# %% [markdown]
# AI-Powered Urban Climate Resilience Dashboard for Indian Cities

# %%
# 1. Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 2. Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# 3. Load datasets
df1 = pd.read_csv("/content/drive/MyDrive/climate_datasets/daily-rainfall-at-state-level.csv")
df2 = pd.read_csv("/content/drive/MyDrive/climate_datasets/air_pollution_data.csv")
df3 = pd.read_csv("/content/drive/MyDrive/climate_datasets/air-quality-india.csv")



# === DATASET 1 ===
print("=== DATASET 1 INFO ===")
print(df1.info())

print("\n=== DATASET 1 SUMMARY ===")
print(df1.describe())

print("\n=== DATASET 1 MISSING VALUES ===")
print(df1.isnull().sum())

# === DATASET 2 ===
print("\n\n=== DATASET 2 INFO ===")
print(df2.info())

print("\n=== DATASET 2 SUMMARY ===")
print(df2.describe())

print("\n=== DATASET 2 MISSING VALUES ===")
print(df2.isnull().sum())

# === DATASET 3 ===
print("\n\n=== DATASET 3 INFO ===")
print(df3.info())

print("\n=== DATASET 3 SUMMARY ===")
print(df3.describe())

print("\n=== DATASET 3 MISSING VALUES ===")
print(df3.isnull().sum())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# === DATASET 1 INFO ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204876 entries, 0 to 204875
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   id          204876 non-null  int64
#  1   date        204876 non-null  object
#  2   state_code  204876 non-null  int64
#  3   state_name  204876 non-null  object
#  4   actual      187714 non-null  float64
#  5   rfs         199011 non-null  float64
#  6   normal      193358 non-null  float64
#  7   deviation   173855 non-null  float64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 12.5+ MB
# None
#
# === DATASET 1 SUMMARY ===
#                   id     state_code         actual            rfs  \
# count  204876.000000  204876.000000  187714.000000  199011.000000
# ...
